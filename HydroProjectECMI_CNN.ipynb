# %% [markdown]
# <a href="https://colab.research.google.com/github/beingnator/ECMI-hydrological-forecasting/blob/main/HydroProjectECMI_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pytorch CNN

# %%
#Importing libraries
import seaborn as sns
import torch
import torch.nn.functional as F
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

#Manually setting a seed for random generators. This way the results can be reproduced.
torch.manual_seed(42)
random.seed(42)
np.random.seed(42)

# %%
#Downloading the created training and validation files and maximum correlation values for the spatial model
# !gdown --id 1t2xlzVbw_Oc6pYrUk5ntQP55shUllgRK
# !gdown --id 1xjTRjbiBVltExeSKePUyFrP-UvpJpbAb
# !gdown --id 14tlqDh2cJG75sQO-uTmB9NcGOxKB7c5l
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1t2xlzVbw_Oc6pYrUk5ntQP55shUllgRK
# To: /content/data_training.csv
# 100% 7.13M/7.13M [00:00<00:00, 90.9MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1xjTRjbiBVltExeSKePUyFrP-UvpJpbAb
# To: /content/data_validation.csv
# 100% 1.71M/1.71M [00:00<00:00, 134MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=14tlqDh2cJG75sQO-uTmB9NcGOxKB7c5l
# To: /content/maximum_correlation.csv
# 100% 348/348 [00:00<00:00, 1.58MB/s]

# %%
#Reading the files containing the preprocessed training and validation datas, including a split.
#The split makes sure that there is at least one flood in both dataset.
data_train = pd.read_csv("data_training.csv",index_col=0)
data_valid = pd.read_csv("data_validation.csv",index_col=0)
max_corr = pd.read_csv("maximum_correlation.csv",index_col=0)
#Changing the data format of the index columns.
data_train.index = pd.to_datetime(data_train.index)
data_valid.index = pd.to_datetime(data_valid.index)
#Sorting the columns according to the distance between the stations
#calculated from the maximal correlations.
max_corr.columns = ["Distance"]
data_train = data_train[list(map(str, max_corr.sort_values(by = ["Distance"]).index.to_list()))]
data_valid = data_valid[list(map(str, max_corr.sort_values(by = ["Distance"]).index.to_list()))]

# %%
colnum = len(data_train.columns.tolist()) #Number of stations
pastWindow = 15 #Number of days before prediction
windowSize = 7 #Number of predicted days

# %%
#This function requires the dataset, the number of days before the prediction and the number of the columns
#and gives back a torch tensor with a sliding window along time, selecting pastWindow size tensors.
def gen_X_tensor(dataset, pastWindow, colnum):
  windowed_data = np.lib.stride_tricks.sliding_window_view(dataset, (pastWindow,colnum)).reshape((-1,pastWindow,colnum))
  return torch.tensor(windowed_data, dtype = torch.float32)

#This function requires the dataset and the number of days, which needed to be predicted.
#Gives back the following windowSize days as the ground truth water level in Szeged.
def gen_y_tensor(dataset, windowSize):
  y_vals = []
  for i in range(len(dataset)-windowSize+1):
    days = []
    for j in range(windowSize):
      days.append(dataset["2275"].values[i+j])
    y_vals.append(days)
  return torch.reshape(torch.tensor(y_vals, dtype = torch.float32),(-1,windowSize))

# %%
#Creating the training/validation input datas. Because the predicted ground truth days
#should be from the training/validation datas as well, the last windowSize days cannot be
#included into the training/validation data.
X_train = gen_X_tensor(data_train[:-windowSize], pastWindow, colnum)
X_valid = gen_X_tensor(data_valid[:-windowSize], pastWindow, colnum)

CNNnumpy = torch.Tensor(data_train.to_numpy()) #Tensor from pandas dataframe
means = CNNnumpy.mean(axis=0, keepdims=True) #Mean of the training data
stds = CNNnumpy.std(axis=0, keepdims=True) #Standard deviation of the training data
X_train = (X_train - means) / stds #Standardized training input
X_valid = (X_valid - means) / stds #Standardized validation input

#Generation of the ground truth output vectors, with windowSize. The first pastWindow size
#cannot be used, because there is not enough past size before that.
y_train = gen_y_tensor(data_train[pastWindow:],windowSize)
y_valid = gen_y_tensor(data_valid[pastWindow:],windowSize)
#Mean and Standard Deviation of Szeged.
y_mean = torch.full((1,7),means[0,3])
y_stds = torch.full((1,7),stds[0,3])
#Standardization of the training and validation datas.
y_train = (y_train - y_mean) / y_stds
y_valid = (y_valid - y_mean) / y_stds
#Check if the number of the input and output equal to each other.
print(f"Number of input: {len(X_train)}\t Number of output: {len(y_train)}")
#Change dimensions to be able to use them in the CNN network.
X_train = torch.transpose(X_train,1,2)
X_valid = torch.transpose(X_valid,1,2)
# Out:
# Number of input: 19705	 Number of output: 19705

# %%
#Predefinition of the increasing size of channels. This way we provide more and more informations
#in the layers being deeper and deeper, so the spatial information is included in a way
#that the deeper the layer is the larger region of interest it has.
channelSize = []
for i in range(7):
  channelSize.append(max_corr[max_corr.Distance <= i].count().values[0])

# %%
import torch.nn as nn

#Simple CNN module with 3 1D convolutional layer. The convolution only goes along the
#time using all the stations as channels. The kernel_size is picked in a way that
#the output dimension should be allright.
class HydroForecast(nn.Module):
    #definition of the CNN layer
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Conv1d(colnum, 7, kernel_size=5),
            nn.ReLU(),
            nn.Conv1d(7, 7, kernel_size=9),
            nn.ReLU(),
            nn.Conv1d(7, 7, kernel_size=3))

    #creating the forward flow
    def forward(self, x):
      x = self.model(x)
      return x.reshape(-1,7)

#Creating layers for different distances away from Szeged. The deeper the network the further the network sees.
class HydroForecastSpatialVersion(nn.Module):
    def __init__(self):
        super().__init__()
        self.Day1Model = nn.Sequential(
            nn.Conv1d(channelSize[0], channelSize[0], kernel_size=1),
            nn.ReLU())
        self.Day2Model = nn.Sequential(
            nn.Conv1d(channelSize[1], channelSize[1], kernel_size=1),
            nn.ReLU())
        self.Day3Model = nn.Sequential(
            nn.Conv1d(channelSize[2], channelSize[2], kernel_size=1),
            nn.ReLU())
        self.Day4Model = nn.Sequential(
            nn.Conv1d(channelSize[3], channelSize[3], kernel_size=1),
            nn.ReLU())
        self.Day5Model = nn.Sequential(
            nn.Conv1d(channelSize[4], channelSize[4], kernel_size=1),
            nn.ReLU())
        self.Day6Model = nn.Sequential(
            nn.Conv1d(channelSize[5], channelSize[5], kernel_size=1),
            nn.ReLU())
        self.Day7Model = nn.Sequential(
            nn.Conv1d(channelSize[6], colnum, kernel_size=1),
            nn.ReLU())
        #At the end the simplest CNN network is attached.
        self.model = nn.Sequential(
            nn.Conv1d(colnum, 7, kernel_size=5),
            nn.ReLU(),
            nn.Conv1d(7, 7, kernel_size=9),
            nn.ReLU(),
            nn.Conv1d(7, 7, kernel_size=3))

    #Building the forward flow of the network.
    def forward(self, x):
      xw = x[:,0:channelSize[0],:]
      xw = self.Day1Model(xw)
      xw = torch.cat((xw, x[:,channelSize[0]:channelSize[1]]),1)
      xw = self.Day2Model(xw)
      xw = torch.cat((xw, x[:,channelSize[1]:channelSize[2]]),1)
      xw = self.Day3Model(xw)
      xw = torch.cat((xw, x[:,channelSize[2]:channelSize[3]]),1)
      xw = self.Day4Model(xw)
      xw = torch.cat((xw, x[:,channelSize[3]:channelSize[4]]),1)
      xw = self.Day5Model(xw)
      xw = torch.cat((xw, x[:,channelSize[4]:channelSize[5]]),1)
      xw = self.Day6Model(xw)
      xw = torch.cat((xw, x[:,channelSize[5]:channelSize[6]]),1)
      xw = self.Day7Model(xw)
      xw = self.model(xw)
      return xw.reshape(-1,7)

# %%
#Definition of loss function, by adding weights to stations in a way that:
#The closer the station is in time, the bigger the loss is.
def mylossW(output, target, weight):
  loss = torch.mean((torch.div(output - target,weight[:output.shape[0]]))**2)
  return loss

#Linear definition of the weigths. The weights according to these settings are linearly increasing numbers from 1 to the end of the predicted timeperiod.
w = []
for batch_iter in range(0,len(y_train)):
    wdays = []
    w.append(np.linspace(1,1,windowSize))
w =torch.Tensor(w)
# Out:
# <ipython-input-13-f118007eb277>:12: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   w =torch.Tensor(w)

# %%
def my_loss1(output, target, weight): #custom relu
  relu_breakpoint_Y = 0.4   #what weight all the small water-level datas get
  relu_breakpoint_X = 0.3   #where the weight-increasing starts

  loss = torch.mean((torch.div((output - target)*(        (target < relu_breakpoint_X) * relu_breakpoint_Y + (target >= relu_breakpoint_X) * (relu_breakpoint_Y + target - relu_breakingpoint_X)        ),weight[:output.shape[0]]))**2)
  return loss

# %%
def my_loss2(output, target, weight): #custom relu squared
  relu_breakpoint_Y = 0.4   #what weight all the small water-level datas get
  relu_breakpoint_X = 0.3   #where the weight-increasing starts

  loss = torch.mean((torch.div((output - target)*(        (target < relu_breakpoint_X) * relu_breakpoint_Y + (target >= relu_breakpoint_X) * (relu_breakpoint_Y + target - relu_breakingpoint_X)**2        ),weight[:output.shape[0]]))**2)
  return loss

# %%
def my_loss3(output, target, weight): #custom two section squared If[x < 0, -x^2/5 + 1, x^2 + 1]

  loss = torch.mean((torch.div((output - target)*(        (target < 0) *((target**2) * (-0.2) + 1) + (target >= 0) * (target**2 + 1)     ),weight[:output.shape[0]]))**2)
  return loss

# %%
def my_loss4(output, target, weight): #custom staircase function
  starting_value = 0.5

  step1x = 0.2
  step1y = 0.7

  step2x = 0.5
  step2y = 1

  step3x = 0.8
  step3y = 1.5

  loss = torch.mean((torch.div((output - target)*(      (target < step1x)*starting_value + (step1x < target)*(target < step2x)*step1y + (step2x < target)*(target < step3x)*step2y + (step3x < target)*step3y          ),weight[:output.shape[0]]))**2)
  return loss

# %%
#Transformation back from the standardized form of data.
def eval_back(y_vals, means, sdts):
  return y_vals*sdts+means

# %%
import numpy as np
import torch.optim as optim
import torch.utils.data as data

#Manually setting a seed for random generators. This way the results can be reproduced.
torch.manual_seed(42)
random.seed(42)
np.random.seed(42)

#Make an instance from the deep learning model.
model = HydroForecast()
#Alias for myloss to specify which loss function should be used
my_loss = mylossW
#Define batchSize
batchSize = 8

#Adam optimizer creation.
optimizer = optim.Adam(model.parameters())
#Scheduler to reduce learnin rate on plateau.
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min')

#Data loader
loader = data.DataLoader(data.TensorDataset(X_train, y_train), shuffle=True, batch_size=batchSize)

n_epochs = 500 #Number of epochs
last_loss = 100 #Initial last_loss value for early stopping.
patience = 10 #Patience of early stopping
trigger_times = 0 #How many times was worse or result than before?

#Training
for epoch in range(n_epochs):
    model.train() #switch to train mode
    #For every batch, making prediction, calculating loss and then use optimizer.
    #This is the standard workflow of Pytorch.
    for X_batch, y_batch in loader: #Loading data in batches
        y_pred = model(X_batch) #make prediction
        loss = my_loss(y_pred, y_batch,w) #calculate loss
        optimizer.zero_grad() #zero the optimizer
        loss.backward() #calculate backpropogation
        optimizer.step() #make an optimization step
    model.eval() #switch evaluation mode
    with torch.inference_mode(): #inference_mode on
        #Loss of training and loss of validation is calculated here.
        #Standard workflow for validation
        y_pred = model(X_train) #make prediction in training
        train_rmse = np.sqrt(my_loss(y_pred, y_train,w)) #calculate loss
        y_pred = model(X_valid) #make prediction in validation
        valid_rmse = np.sqrt(my_loss(y_pred, y_valid,w)) #calculate loss
        print(f"Prediction: {eval_back(y_pred[1],y_mean,y_stds)}\nGround truth: {eval_back(y_valid[1],y_mean,y_stds)}")
    print(f"Epoch %d: train loss %.4f, validation loss %.4f" % (epoch, train_rmse, valid_rmse))
     # Early stopping
    current_loss = valid_rmse #Value of the current loss
    print('Current Loss: %.4f\t Last Loss: %.4f' % (current_loss,last_loss))

    #If current loss is worse or close to the current loss, trigger
    if last_loss-current_loss < 1e-5:
      trigger_times += 1
      print(f'Trigger Times: {trigger_times}')
    else:
      trigger_times = 0 #reset trigger

    #If the number of trigger times is larger of equal to patience number training over
    if trigger_times >= patience:
      print('Early stopping!\nStart to test process.')
      break
    print(f'trigger times: {trigger_times}')

    #Last loss equals to current loss
    last_loss = current_loss
    #Giving validation loss for the scheduler
    scheduler.step(valid_rmse)
# Out:
# Prediction: tensor([[219.0875, 207.2457, 202.5524, 195.3435, 200.3463, 194.8847, 202.2698]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 0: train loss 0.2208, validation loss 0.1644
# Current Loss: 0.1644	 Last Loss: 100.0000
# trigger times: 0
# Prediction: tensor([[227.7005, 217.0566, 207.0986, 198.3255, 202.6322, 198.8045, 197.6911]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 1: train loss 0.1906, validation loss 0.1610
# Current Loss: 0.1610	 Last Loss: 0.1644
# trigger times: 0
# Prediction: tensor([[230.6113, 222.8129, 202.9823, 192.9484, 194.6971, 190.0906, 191.7799]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 2: train loss 0.1880, validation loss 0.1789
# Current Loss: 0.1789	 Last Loss: 0.1610
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[224.3142, 211.2612, 188.8936, 176.8887, 173.2155, 166.0310, 170.1372]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 3: train loss 0.1857, validation loss 0.1506
# Current Loss: 0.1506	 Last Loss: 0.1789
# trigger times: 0
# Prediction: tensor([[220.6363, 208.4440, 182.9326, 169.2435, 164.2526, 159.0771, 166.6220]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 4: train loss 0.1789, validation loss 0.1590
# Current Loss: 0.1590	 Last Loss: 0.1506
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[223.6295, 206.9862, 185.5305, 172.5211, 165.6408, 161.8723, 167.0907]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 5: train loss 0.1791, validation loss 0.1538
# Current Loss: 0.1538	 Last Loss: 0.1590
# trigger times: 0
# Prediction: tensor([[200.7799, 185.3028, 167.3980, 154.8014, 148.2258, 145.8357, 149.0502]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 6: train loss 0.1834, validation loss 0.1575
# Current Loss: 0.1575	 Last Loss: 0.1538
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[212.1560, 198.1016, 180.0822, 165.3468, 155.1739, 149.8062, 153.4793]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 7: train loss 0.1934, validation loss 0.1675
# Current Loss: 0.1675	 Last Loss: 0.1575
# Trigger Times: 2
# trigger times: 2
# Prediction: tensor([[222.9557, 206.3565, 188.0549, 175.1888, 168.4727, 163.4880, 163.3356]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 8: train loss 0.1750, validation loss 0.1470
# Current Loss: 0.1470	 Last Loss: 0.1675
# trigger times: 0
# Prediction: tensor([[219.7437, 204.9494, 184.3774, 168.3386, 160.5629, 157.3722, 159.0056]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 9: train loss 0.2061, validation loss 0.1789
# Current Loss: 0.1789	 Last Loss: 0.1470
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[214.9424, 194.9608, 174.8415, 161.0936, 154.8581, 153.5368, 157.2624]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 10: train loss 0.1849, validation loss 0.1509
# Current Loss: 0.1509	 Last Loss: 0.1789
# trigger times: 0
# Prediction: tensor([[220.9265, 205.9483, 185.9377, 173.0549, 165.6581, 159.2589, 157.4330]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 11: train loss 0.1814, validation loss 0.1474
# Current Loss: 0.1474	 Last Loss: 0.1509
# trigger times: 0
# Prediction: tensor([[205.9159, 188.9117, 167.2421, 152.0789, 143.2545, 135.6466, 130.2680]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 12: train loss 0.1850, validation loss 0.1582
# Current Loss: 0.1582	 Last Loss: 0.1474
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[212.6780, 195.3721, 174.9772, 160.1384, 153.1935, 149.6542, 148.6311]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 13: train loss 0.1815, validation loss 0.1686
# Current Loss: 0.1686	 Last Loss: 0.1582
# Trigger Times: 2
# trigger times: 2
# Prediction: tensor([[217.5415, 196.4572, 174.5241, 162.0203, 154.6578, 149.1594, 150.1924]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 14: train loss 0.1894, validation loss 0.1719
# Current Loss: 0.1719	 Last Loss: 0.1686
# Trigger Times: 3
# trigger times: 3
# Prediction: tensor([[222.9717, 202.5108, 176.8750, 162.3598, 158.0995, 157.8198, 160.0956]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 15: train loss 0.1732, validation loss 0.1664
# Current Loss: 0.1664	 Last Loss: 0.1719
# trigger times: 0
# Prediction: tensor([[229.3876, 216.1702, 198.6575, 187.3590, 179.8265, 174.2936, 176.4152]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 16: train loss 0.1755, validation loss 0.1495
# Current Loss: 0.1495	 Last Loss: 0.1664
# trigger times: 0
# Prediction: tensor([[204.1198, 184.4222, 163.3544, 147.1428, 142.9976, 145.6374, 145.1204]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 17: train loss 0.1723, validation loss 0.1554
# Current Loss: 0.1554	 Last Loss: 0.1495
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[221.1594, 206.5708, 191.4730, 179.6923, 175.6669, 177.4505, 180.6953]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 18: train loss 0.1750, validation loss 0.1566
# Current Loss: 0.1566	 Last Loss: 0.1554
# Trigger Times: 2
# trigger times: 2
# Prediction: tensor([[216.5692, 200.1827, 182.8985, 167.1466, 159.2992, 156.9457, 153.6895]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 19: train loss 0.1744, validation loss 0.1589
# Current Loss: 0.1589	 Last Loss: 0.1566
# Trigger Times: 3
# trigger times: 3
# Prediction: tensor([[219.0275, 203.1900, 186.1691, 173.6997, 168.9842, 168.9472, 168.8006]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 20: train loss 0.1640, validation loss 0.1451
# Current Loss: 0.1451	 Last Loss: 0.1589
# trigger times: 0
# Prediction: tensor([[219.8421, 204.6203, 187.3843, 174.6252, 169.3440, 168.1123, 168.3085]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 21: train loss 0.1652, validation loss 0.1456
# Current Loss: 0.1456	 Last Loss: 0.1451
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[219.4009, 203.1000, 184.8812, 171.7291, 166.1829, 164.4704, 164.8749]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 22: train loss 0.1629, validation loss 0.1439
# Current Loss: 0.1439	 Last Loss: 0.1456
# trigger times: 0
# Prediction: tensor([[219.9059, 203.2095, 185.2608, 171.3844, 165.0527, 163.4458, 163.1720]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 23: train loss 0.1620, validation loss 0.1462
# Current Loss: 0.1462	 Last Loss: 0.1439
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[217.9176, 201.8168, 184.1835, 170.9248, 165.6189, 164.7566, 165.7702]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 24: train loss 0.1622, validation loss 0.1461
# Current Loss: 0.1461	 Last Loss: 0.1462
# trigger times: 0
# Prediction: tensor([[220.9871, 204.7274, 186.7236, 172.2586, 165.6809, 164.2433, 164.8616]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 25: train loss 0.1621, validation loss 0.1448
# Current Loss: 0.1448	 Last Loss: 0.1461
# trigger times: 0
# Prediction: tensor([[220.0083, 201.9369, 183.3755, 168.5794, 161.4725, 159.5427, 159.5111]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 26: train loss 0.1617, validation loss 0.1459
# Current Loss: 0.1459	 Last Loss: 0.1448
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[220.1713, 203.1484, 184.3238, 169.2179, 162.4563, 161.0242, 161.2489]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 27: train loss 0.1620, validation loss 0.1491
# Current Loss: 0.1491	 Last Loss: 0.1459
# Trigger Times: 2
# trigger times: 2
# Prediction: tensor([[220.1360, 203.7034, 185.8694, 171.6636, 164.8120, 161.9425, 161.2410]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 28: train loss 0.1614, validation loss 0.1487
# Current Loss: 0.1487	 Last Loss: 0.1491
# trigger times: 0
# Prediction: tensor([[222.3551, 205.2089, 186.9828, 172.6617, 166.4065, 164.7469, 164.6341]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 29: train loss 0.1633, validation loss 0.1446
# Current Loss: 0.1446	 Last Loss: 0.1487
# trigger times: 0
# Prediction: tensor([[222.6696, 205.3868, 186.2749, 170.7088, 163.7672, 161.3081, 160.8280]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 30: train loss 0.1618, validation loss 0.1423
# Current Loss: 0.1423	 Last Loss: 0.1446
# trigger times: 0
# Prediction: tensor([[220.8248, 203.8095, 184.5984, 168.8093, 161.8368, 160.2675, 160.5024]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 31: train loss 0.1616, validation loss 0.1471
# Current Loss: 0.1471	 Last Loss: 0.1423
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[223.8897, 206.2884, 186.5110, 170.6596, 163.5289, 161.5762, 161.5972]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 32: train loss 0.1611, validation loss 0.1465
# Current Loss: 0.1465	 Last Loss: 0.1471
# trigger times: 0
# Prediction: tensor([[221.9991, 202.2764, 180.6234, 163.2083, 155.4886, 154.1537, 154.0006]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 33: train loss 0.1615, validation loss 0.1454
# Current Loss: 0.1454	 Last Loss: 0.1465
# trigger times: 0
# Prediction: tensor([[222.5380, 203.9131, 183.5381, 167.3603, 159.7267, 157.4428, 157.2110]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 34: train loss 0.1609, validation loss 0.1461
# Current Loss: 0.1461	 Last Loss: 0.1454
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[224.2341, 206.1697, 186.5074, 170.9299, 163.9077, 161.9515, 162.1659]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 35: train loss 0.1621, validation loss 0.1496
# Current Loss: 0.1496	 Last Loss: 0.1461
# Trigger Times: 2
# trigger times: 2
# Prediction: tensor([[221.3672, 203.2264, 183.1113, 167.3938, 160.5076, 159.3013, 159.9536]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 36: train loss 0.1609, validation loss 0.1456
# Current Loss: 0.1456	 Last Loss: 0.1496
# trigger times: 0
# Prediction: tensor([[225.3831, 206.9686, 186.9083, 171.1167, 163.8314, 161.4372, 161.4274]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 37: train loss 0.1620, validation loss 0.1475
# Current Loss: 0.1475	 Last Loss: 0.1456
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[225.3614, 207.0850, 186.2183, 169.4641, 161.7699, 159.5170, 160.1827]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 38: train loss 0.1610, validation loss 0.1450
# Current Loss: 0.1450	 Last Loss: 0.1475
# trigger times: 0
# Prediction: tensor([[223.3895, 204.3093, 183.4166, 166.7514, 159.4863, 158.0723, 159.2483]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 39: train loss 0.1617, validation loss 0.1487
# Current Loss: 0.1487	 Last Loss: 0.1450
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[224.3002, 205.1705, 183.9259, 167.0276, 159.0255, 156.1783, 156.0174]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 40: train loss 0.1609, validation loss 0.1474
# Current Loss: 0.1474	 Last Loss: 0.1487
# trigger times: 0
# Prediction: tensor([[223.2123, 205.1468, 184.9860, 168.7516, 161.3515, 159.8201, 160.4815]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 41: train loss 0.1607, validation loss 0.1452
# Current Loss: 0.1452	 Last Loss: 0.1474
# trigger times: 0
# Prediction: tensor([[223.7774, 204.9753, 184.2653, 167.5347, 159.5363, 157.0172, 157.2005]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 42: train loss 0.1601, validation loss 0.1456
# Current Loss: 0.1456	 Last Loss: 0.1452
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[223.7000, 204.7730, 184.0061, 167.0786, 159.0959, 156.7015, 156.7887]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 43: train loss 0.1600, validation loss 0.1455
# Current Loss: 0.1455	 Last Loss: 0.1456
# trigger times: 0
# Prediction: tensor([[223.5542, 204.6396, 183.8084, 166.7887, 158.5251, 155.8206, 155.7267]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 44: train loss 0.1601, validation loss 0.1457
# Current Loss: 0.1457	 Last Loss: 0.1455
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[224.0325, 205.1606, 184.3298, 167.4345, 159.2511, 156.5288, 156.4317]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 45: train loss 0.1600, validation loss 0.1456
# Current Loss: 0.1456	 Last Loss: 0.1457
# trigger times: 0
# Prediction: tensor([[224.1736, 205.1589, 184.2501, 167.4566, 159.4352, 156.8506, 156.8101]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 46: train loss 0.1600, validation loss 0.1454
# Current Loss: 0.1454	 Last Loss: 0.1456
# trigger times: 0
# Prediction: tensor([[224.1022, 205.1537, 184.3127, 167.3371, 159.0849, 156.3756, 156.4790]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 47: train loss 0.1600, validation loss 0.1456
# Current Loss: 0.1456	 Last Loss: 0.1454
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[224.1864, 205.3707, 184.5916, 167.8521, 159.6099, 156.8269, 156.8604]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 48: train loss 0.1599, validation loss 0.1459
# Current Loss: 0.1459	 Last Loss: 0.1456
# Trigger Times: 2
# trigger times: 2
# Prediction: tensor([[223.7731, 204.7937, 184.0146, 167.2253, 159.1697, 156.4982, 156.5432]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 49: train loss 0.1599, validation loss 0.1458
# Current Loss: 0.1458	 Last Loss: 0.1459
# trigger times: 0
# Prediction: tensor([[224.2466, 205.2211, 184.3265, 167.4453, 159.2994, 156.6042, 156.6059]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 50: train loss 0.1599, validation loss 0.1458
# Current Loss: 0.1458	 Last Loss: 0.1458
# trigger times: 0
# Prediction: tensor([[224.0314, 205.2776, 184.5815, 167.8037, 159.6775, 156.9802, 156.9073]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 51: train loss 0.1599, validation loss 0.1454
# Current Loss: 0.1454	 Last Loss: 0.1458
# trigger times: 0
# Prediction: tensor([[224.2573, 205.0896, 184.0837, 167.2285, 159.0533, 156.3106, 156.2009]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 52: train loss 0.1599, validation loss 0.1458
# Current Loss: 0.1458	 Last Loss: 0.1454
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[224.0710, 205.0088, 184.1227, 167.2391, 159.1201, 156.4283, 156.3864]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 53: train loss 0.1599, validation loss 0.1459
# Current Loss: 0.1459	 Last Loss: 0.1458
# Trigger Times: 2
# trigger times: 2
# Prediction: tensor([[224.0345, 205.0267, 184.1829, 167.2850, 159.1496, 156.4703, 156.4543]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 54: train loss 0.1599, validation loss 0.1458
# Current Loss: 0.1458	 Last Loss: 0.1459
# trigger times: 0
# Prediction: tensor([[224.1231, 205.1507, 184.3334, 167.4141, 159.2414, 156.5464, 156.5483]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 55: train loss 0.1599, validation loss 0.1459
# Current Loss: 0.1459	 Last Loss: 0.1458
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[224.0893, 205.0929, 184.2535, 167.3690, 159.2170, 156.5357, 156.5585]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 56: train loss 0.1599, validation loss 0.1460
# Current Loss: 0.1460	 Last Loss: 0.1459
# Trigger Times: 2
# trigger times: 2
# Prediction: tensor([[224.1241, 205.1517, 184.3017, 167.4205, 159.2959, 156.6432, 156.6714]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 57: train loss 0.1599, validation loss 0.1458
# Current Loss: 0.1458	 Last Loss: 0.1460
# trigger times: 0
# Prediction: tensor([[224.1241, 205.1497, 184.3223, 167.4536, 159.3186, 156.6544, 156.6908]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 58: train loss 0.1599, validation loss 0.1458
# Current Loss: 0.1458	 Last Loss: 0.1458
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[224.0703, 205.1249, 184.2800, 167.4174, 159.2836, 156.6117, 156.6549]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 59: train loss 0.1599, validation loss 0.1459
# Current Loss: 0.1459	 Last Loss: 0.1458
# Trigger Times: 2
# trigger times: 2
# Prediction: tensor([[224.0769, 205.0933, 184.2771, 167.4338, 159.3190, 156.6539, 156.6970]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 60: train loss 0.1599, validation loss 0.1459
# Current Loss: 0.1459	 Last Loss: 0.1459
# Trigger Times: 3
# trigger times: 3
# Prediction: tensor([[224.1249, 205.1443, 184.3352, 167.4763, 159.3452, 156.6737, 156.7166]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 61: train loss 0.1599, validation loss 0.1459
# Current Loss: 0.1459	 Last Loss: 0.1459
# trigger times: 0
# Prediction: tensor([[224.0849, 205.1625, 184.3801, 167.5200, 159.3671, 156.6835, 156.7160]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 62: train loss 0.1599, validation loss 0.1458
# Current Loss: 0.1458	 Last Loss: 0.1459
# trigger times: 0
# Prediction: tensor([[224.0339, 205.0829, 184.3173, 167.5058, 159.3915, 156.7227, 156.7640]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 63: train loss 0.1599, validation loss 0.1459
# Current Loss: 0.1459	 Last Loss: 0.1458
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[224.0501, 205.1008, 184.3279, 167.5110, 159.3944, 156.7245, 156.7654]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 64: train loss 0.1599, validation loss 0.1459
# Current Loss: 0.1459	 Last Loss: 0.1459
# trigger times: 0
# Prediction: tensor([[224.0619, 205.1137, 184.3345, 167.5129, 159.3957, 156.7270, 156.7680]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 65: train loss 0.1599, validation loss 0.1459
# Current Loss: 0.1459	 Last Loss: 0.1459
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[224.0735, 205.1258, 184.3430, 167.5191, 159.4009, 156.7326, 156.7735]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 66: train loss 0.1599, validation loss 0.1459
# Current Loss: 0.1459	 Last Loss: 0.1459
# Trigger Times: 2
# trigger times: 2
# Prediction: tensor([[224.0808, 205.1335, 184.3470, 167.5213, 159.4028, 156.7342, 156.7748]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 67: train loss 0.1599, validation loss 0.1459
# Current Loss: 0.1459	 Last Loss: 0.1459
# Trigger Times: 3
# trigger times: 3
# Prediction: tensor([[224.0841, 205.1380, 184.3503, 167.5238, 159.4059, 156.7379, 156.7792]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 68: train loss 0.1599, validation loss 0.1458
# Current Loss: 0.1458	 Last Loss: 0.1459
# Trigger Times: 4
# trigger times: 4
# Prediction: tensor([[224.0891, 205.1436, 184.3544, 167.5264, 159.4072, 156.7389, 156.7800]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 69: train loss 0.1599, validation loss 0.1458
# Current Loss: 0.1458	 Last Loss: 0.1458
# Trigger Times: 5
# trigger times: 5
# Prediction: tensor([[224.0909, 205.1472, 184.3577, 167.5295, 159.4103, 156.7423, 156.7836]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 70: train loss 0.1599, validation loss 0.1458
# Current Loss: 0.1458	 Last Loss: 0.1458
# Trigger Times: 6
# trigger times: 6
# Prediction: tensor([[224.0914, 205.1485, 184.3578, 167.5297, 159.4104, 156.7426, 156.7838]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 71: train loss 0.1599, validation loss 0.1459
# Current Loss: 0.1459	 Last Loss: 0.1458
# Trigger Times: 7
# trigger times: 7
# Prediction: tensor([[224.0881, 205.1471, 184.3574, 167.5305, 159.4131, 156.7463, 156.7883]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 72: train loss 0.1599, validation loss 0.1458
# Current Loss: 0.1458	 Last Loss: 0.1459
# Trigger Times: 8
# trigger times: 8
# Prediction: tensor([[224.0895, 205.1483, 184.3580, 167.5309, 159.4129, 156.7466, 156.7883]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 73: train loss 0.1599, validation loss 0.1458
# Current Loss: 0.1458	 Last Loss: 0.1458
# Trigger Times: 9
# trigger times: 9
# Prediction: tensor([[224.0913, 205.1501, 184.3593, 167.5326, 159.4142, 156.7486, 156.7907]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 74: train loss 0.1599, validation loss 0.1458
# Current Loss: 0.1458	 Last Loss: 0.1458
# Trigger Times: 10
# Early stopping!
# Start to test process.

# %%
import numpy as np
import torch.optim as optim
import torch.utils.data as data

#Manually setting a seed for random generators. This way the results can be reproduced.
torch.manual_seed(42)
random.seed(42)
np.random.seed(42)

#Make an instance from the deep learning model.
modelSpat = HydroForecastSpatialVersion()
#Alias for myloss to specify which loss function should be used
my_loss = mylossW
#Define batchSize
batchSize = 8

#Adam optimizer creation.
optimizer = optim.Adam(modelSpat.parameters())
#Scheduler to reduce learnin rate on plateau.
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min')

#Data loader
loader = data.DataLoader(data.TensorDataset(X_train, y_train), shuffle=True, batch_size=batchSize)

n_epochs = 500 #Number of epochs
last_loss = 100 #Initial last_loss value for early stopping.
patience = 10 #Patience of early stopping
trigger_times = 0 #How many times was worse or result than before?

#Training
for epoch in range(n_epochs):
    modelSpat.train() #switch to train mode
    #For every batch, making prediction, calculating loss and then use optimizer.
    #This is the standard workflow of Pytorch.
    for X_batch, y_batch in loader: #Loading data in batches
        y_pred = modelSpat(X_batch) #make prediction
        loss = my_loss(y_pred, y_batch,w) #calculate loss
        optimizer.zero_grad() #zero the optimizer
        loss.backward() #calculate backpropogation
        optimizer.step() #make an optimization step
    modelSpat.eval() #switch evaluation mode
    with torch.inference_mode(): #inference_mode on
        #Loss of training and loss of validation is calculated here.
        #Standard workflow for validation
        y_pred = modelSpat(X_train) #make prediction in training
        train_rmse = np.sqrt(my_loss(y_pred, y_train,w)) #calculate loss
        y_pred = modelSpat(X_valid) #make prediction in validation
        valid_rmse = np.sqrt(my_loss(y_pred, y_valid,w)) #calculate loss
        print(f"Prediction: {eval_back(y_pred[1],y_mean,y_stds)}\nGround truth: {eval_back(y_valid[1],y_mean,y_stds)}")
    print(f"Epoch %d: train loss %.4f, validation loss %.4f" % (epoch, train_rmse, valid_rmse))
     # Early stopping
    current_loss = valid_rmse #Value of the current loss
    print('Current Loss: %.4f\t Last Loss: %.4f' % (current_loss,last_loss))

    #If current loss is worse or close to the current loss, trigger
    if last_loss-current_loss < 1e-5:
      trigger_times += 1
      print(f'Trigger Times: {trigger_times}')
    else:
      trigger_times = 0 #reset trigger

    #If the number of trigger times is larger of equal to patience number training over
    if trigger_times >= patience:
      print('Early stopping!\nStart to test process.')
      break
    print(f'trigger times: {trigger_times}')

    #Last loss equals to current loss
    last_loss = current_loss
    #Giving validation loss for the scheduler
    scheduler.step(valid_rmse)
# Out:
# Prediction: tensor([[214.4546, 200.2396, 198.5512, 189.6375, 186.8123, 183.5941, 179.7700]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 0: train loss 0.2275, validation loss 0.1840
# Current Loss: 0.1840	 Last Loss: 100.0000
# trigger times: 0
# Prediction: tensor([[214.7112, 202.2579, 190.0246, 178.1639, 177.0756, 175.5991, 178.1323]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 1: train loss 0.1871, validation loss 0.1550
# Current Loss: 0.1550	 Last Loss: 0.1840
# trigger times: 0
# Prediction: tensor([[229.2213, 215.8266, 204.9330, 195.6217, 189.2757, 187.9439, 190.1462]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 2: train loss 0.1860, validation loss 0.1560
# Current Loss: 0.1560	 Last Loss: 0.1550
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[223.4918, 212.7811, 207.6844, 202.4059, 202.4026, 207.0791, 213.3328]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 3: train loss 0.1968, validation loss 0.1469
# Current Loss: 0.1469	 Last Loss: 0.1560
# trigger times: 0
# Prediction: tensor([[223.4049, 211.0426, 208.1251, 210.4860, 207.0912, 221.2895, 216.6324]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 4: train loss 0.1836, validation loss 0.1613
# Current Loss: 0.1613	 Last Loss: 0.1469
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[206.6351, 195.3829, 192.3639, 184.8589, 179.8131, 187.3996, 183.7040]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 5: train loss 0.1746, validation loss 0.1594
# Current Loss: 0.1594	 Last Loss: 0.1613
# trigger times: 0
# Prediction: tensor([[223.1354, 214.9466, 217.6294, 224.5393, 226.8439, 249.6341, 242.1181]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 6: train loss 0.1716, validation loss 0.1628
# Current Loss: 0.1628	 Last Loss: 0.1594
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[236.8604, 230.8219, 229.6009, 238.1089, 239.9168, 256.3994, 248.0027]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 7: train loss 0.1670, validation loss 0.1482
# Current Loss: 0.1482	 Last Loss: 0.1628
# trigger times: 0
# Prediction: tensor([[227.1779, 222.4764, 224.9802, 226.6487, 228.0736, 240.3137, 232.6092]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 8: train loss 0.1587, validation loss 0.1528
# Current Loss: 0.1528	 Last Loss: 0.1482
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[223.1919, 221.9524, 229.5548, 236.7072, 246.1406, 260.0512, 256.0104]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 9: train loss 0.1681, validation loss 0.1590
# Current Loss: 0.1590	 Last Loss: 0.1528
# Trigger Times: 2
# trigger times: 2
# Prediction: tensor([[239.0060, 229.9054, 223.7481, 221.4304, 223.5112, 232.0687, 227.8984]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 10: train loss 0.1565, validation loss 0.1544
# Current Loss: 0.1544	 Last Loss: 0.1590
# trigger times: 0
# Prediction: tensor([[232.4656, 228.9748, 231.1107, 232.8986, 234.7819, 243.5419, 237.4617]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 11: train loss 0.1898, validation loss 0.1909
# Current Loss: 0.1909	 Last Loss: 0.1544
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[225.0635, 216.8804, 214.1962, 213.4100, 217.1087, 224.5096, 220.9487]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 12: train loss 0.1553, validation loss 0.1630
# Current Loss: 0.1630	 Last Loss: 0.1909
# trigger times: 0
# Prediction: tensor([[232.7650, 217.3823, 205.6771, 196.3811, 193.3330, 199.3694, 195.3036]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 13: train loss 0.1508, validation loss 0.1528
# Current Loss: 0.1528	 Last Loss: 0.1630
# trigger times: 0
# Prediction: tensor([[246.9189, 239.6695, 242.9525, 250.2462, 260.5293, 279.5619, 280.8835]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 14: train loss 0.1530, validation loss 0.1599
# Current Loss: 0.1599	 Last Loss: 0.1528
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[229.8678, 215.3699, 207.0167, 202.9350, 205.3978, 214.5416, 213.4564]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 15: train loss 0.1333, validation loss 0.1530
# Current Loss: 0.1530	 Last Loss: 0.1599
# trigger times: 0
# Prediction: tensor([[229.9705, 215.7937, 207.6959, 203.1102, 204.9613, 213.3265, 212.4223]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 16: train loss 0.1317, validation loss 0.1528
# Current Loss: 0.1528	 Last Loss: 0.1530
# trigger times: 0
# Prediction: tensor([[223.9177, 209.4306, 201.7911, 197.3616, 198.6602, 205.6527, 204.7308]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 17: train loss 0.1302, validation loss 0.1549
# Current Loss: 0.1549	 Last Loss: 0.1528
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[222.4979, 209.2273, 203.1671, 200.6348, 203.7257, 212.3234, 211.9260]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 18: train loss 0.1302, validation loss 0.1563
# Current Loss: 0.1563	 Last Loss: 0.1549
# Trigger Times: 2
# trigger times: 2
# Prediction: tensor([[223.9298, 210.9984, 204.6512, 201.9250, 206.0260, 215.5650, 216.6150]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 19: train loss 0.1286, validation loss 0.1583
# Current Loss: 0.1583	 Last Loss: 0.1563
# Trigger Times: 3
# trigger times: 3
# Prediction: tensor([[221.5862, 209.2772, 203.1691, 200.9816, 204.9734, 213.7813, 214.6193]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 20: train loss 0.1275, validation loss 0.1566
# Current Loss: 0.1566	 Last Loss: 0.1583
# trigger times: 0
# Prediction: tensor([[219.8269, 208.3277, 202.8495, 201.6564, 206.8272, 215.8898, 217.5587]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 21: train loss 0.1279, validation loss 0.1569
# Current Loss: 0.1569	 Last Loss: 0.1566
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[216.8560, 205.9207, 201.4414, 201.1884, 207.7070, 218.7204, 221.6593]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 22: train loss 0.1267, validation loss 0.1591
# Current Loss: 0.1591	 Last Loss: 0.1569
# Trigger Times: 2
# trigger times: 2
# Prediction: tensor([[219.1920, 208.6966, 204.5830, 205.0542, 212.0768, 223.3190, 226.9120]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 23: train loss 0.1252, validation loss 0.1590
# Current Loss: 0.1590	 Last Loss: 0.1591
# trigger times: 0
# Prediction: tensor([[219.2837, 209.5950, 206.7094, 209.0235, 217.7408, 229.7705, 232.6076]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 24: train loss 0.1259, validation loss 0.1604
# Current Loss: 0.1604	 Last Loss: 0.1590
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[219.1715, 210.6109, 207.3982, 209.0301, 217.6571, 229.8279, 234.1375]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 25: train loss 0.1239, validation loss 0.1583
# Current Loss: 0.1583	 Last Loss: 0.1604
# trigger times: 0
# Prediction: tensor([[218.0585, 209.1695, 206.3995, 208.3178, 217.2554, 230.1057, 234.6901]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 26: train loss 0.1228, validation loss 0.1597
# Current Loss: 0.1597	 Last Loss: 0.1583
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[218.8925, 210.0041, 207.1151, 209.1192, 217.8522, 230.3831, 234.7802]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 27: train loss 0.1226, validation loss 0.1593
# Current Loss: 0.1593	 Last Loss: 0.1597
# trigger times: 0
# Prediction: tensor([[218.3607, 209.3742, 206.6354, 208.8102, 217.6593, 230.4613, 235.0071]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 28: train loss 0.1225, validation loss 0.1598
# Current Loss: 0.1598	 Last Loss: 0.1593
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[218.7948, 209.6663, 207.0264, 209.2851, 218.0363, 230.7018, 235.1008]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 29: train loss 0.1224, validation loss 0.1594
# Current Loss: 0.1594	 Last Loss: 0.1598
# trigger times: 0
# Prediction: tensor([[218.2865, 209.5354, 207.0304, 209.4400, 218.4259, 231.2250, 235.7962]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 30: train loss 0.1223, validation loss 0.1597
# Current Loss: 0.1597	 Last Loss: 0.1594
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[218.5155, 209.8182, 207.2609, 209.7558, 218.8646, 231.5879, 236.2412]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 31: train loss 0.1222, validation loss 0.1594
# Current Loss: 0.1594	 Last Loss: 0.1597
# trigger times: 0
# Prediction: tensor([[218.7056, 209.9126, 207.4153, 210.1046, 219.4007, 232.1830, 236.8477]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 32: train loss 0.1222, validation loss 0.1597
# Current Loss: 0.1597	 Last Loss: 0.1594
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[218.1246, 209.6319, 207.1975, 209.6803, 218.7063, 231.4634, 236.1790]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 33: train loss 0.1221, validation loss 0.1597
# Current Loss: 0.1597	 Last Loss: 0.1597
# Trigger Times: 2
# trigger times: 2
# Prediction: tensor([[218.1369, 209.6425, 207.2346, 209.8222, 218.9134, 231.5885, 236.2586]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 34: train loss 0.1221, validation loss 0.1602
# Current Loss: 0.1602	 Last Loss: 0.1597
# Trigger Times: 3
# trigger times: 3
# Prediction: tensor([[218.0426, 209.6211, 207.2767, 209.8640, 219.0499, 231.7923, 236.4757]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 35: train loss 0.1220, validation loss 0.1604
# Current Loss: 0.1604	 Last Loss: 0.1602
# Trigger Times: 4
# trigger times: 4
# Prediction: tensor([[218.4767, 209.9670, 207.7063, 210.5511, 220.0821, 233.2136, 238.2263]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 36: train loss 0.1220, validation loss 0.1597
# Current Loss: 0.1597	 Last Loss: 0.1604
# trigger times: 0
# Prediction: tensor([[218.3768, 209.8872, 207.5523, 210.2606, 219.6198, 232.6492, 237.6336]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 37: train loss 0.1218, validation loss 0.1602
# Current Loss: 0.1602	 Last Loss: 0.1597
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[218.3436, 209.8790, 207.5431, 210.2334, 219.5211, 232.4881, 237.4368]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 38: train loss 0.1218, validation loss 0.1602
# Current Loss: 0.1602	 Last Loss: 0.1602
# Trigger Times: 2
# trigger times: 2
# Prediction: tensor([[218.3157, 209.8686, 207.5407, 210.2424, 219.5150, 232.4577, 237.3900]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 39: train loss 0.1218, validation loss 0.1602
# Current Loss: 0.1602	 Last Loss: 0.1602
# trigger times: 0
# Prediction: tensor([[218.3193, 209.8772, 207.5134, 210.2013, 219.4552, 232.3739, 237.2988]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 40: train loss 0.1218, validation loss 0.1603
# Current Loss: 0.1603	 Last Loss: 0.1602
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[218.2871, 209.8652, 207.5156, 210.2051, 219.4339, 232.3305, 237.2422]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 41: train loss 0.1218, validation loss 0.1603
# Current Loss: 0.1603	 Last Loss: 0.1603
# trigger times: 0
# Prediction: tensor([[218.2671, 209.8730, 207.5474, 210.2508, 219.4958, 232.4001, 237.3111]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 42: train loss 0.1217, validation loss 0.1602
# Current Loss: 0.1602	 Last Loss: 0.1603
# trigger times: 0
# Prediction: tensor([[218.2892, 209.8755, 207.5389, 210.2417, 219.4868, 232.3897, 237.2956]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 43: train loss 0.1217, validation loss 0.1602
# Current Loss: 0.1602	 Last Loss: 0.1602
# trigger times: 0
# Prediction: tensor([[218.2510, 209.8438, 207.4995, 210.2212, 219.4860, 232.3896, 237.3055]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 44: train loss 0.1217, validation loss 0.1603
# Current Loss: 0.1603	 Last Loss: 0.1602
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[218.3682, 209.9675, 207.6402, 210.3636, 219.6232, 232.5326, 237.4425]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 45: train loss 0.1217, validation loss 0.1601
# Current Loss: 0.1601	 Last Loss: 0.1603
# trigger times: 0
# Prediction: tensor([[218.2938, 209.9107, 207.5836, 210.3187, 219.6007, 232.5295, 237.4547]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 46: train loss 0.1217, validation loss 0.1603
# Current Loss: 0.1603	 Last Loss: 0.1601
# Trigger Times: 1
# trigger times: 1
# Prediction: tensor([[218.2886, 209.9108, 207.5757, 210.3092, 219.5923, 232.5196, 237.4556]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 47: train loss 0.1217, validation loss 0.1603
# Current Loss: 0.1603	 Last Loss: 0.1603
# Trigger Times: 2
# trigger times: 2
# Prediction: tensor([[218.2888, 209.9115, 207.5790, 210.3130, 219.5955, 232.5241, 237.4593]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 48: train loss 0.1217, validation loss 0.1603
# Current Loss: 0.1603	 Last Loss: 0.1603
# Trigger Times: 3
# trigger times: 3
# Prediction: tensor([[218.2893, 209.9126, 207.5828, 210.3170, 219.5998, 232.5297, 237.4658]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 49: train loss 0.1217, validation loss 0.1603
# Current Loss: 0.1603	 Last Loss: 0.1603
# Trigger Times: 4
# trigger times: 4
# Prediction: tensor([[218.2883, 209.9117, 207.5837, 210.3181, 219.6002, 232.5302, 237.4670]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 50: train loss 0.1217, validation loss 0.1603
# Current Loss: 0.1603	 Last Loss: 0.1603
# Trigger Times: 5
# trigger times: 5
# Prediction: tensor([[218.2850, 209.9104, 207.5845, 210.3195, 219.6022, 232.5326, 237.4702]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 51: train loss 0.1217, validation loss 0.1603
# Current Loss: 0.1603	 Last Loss: 0.1603
# Trigger Times: 6
# trigger times: 6
# Prediction: tensor([[218.2834, 209.9097, 207.5860, 210.3230, 219.6071, 232.5390, 237.4776]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 52: train loss 0.1217, validation loss 0.1603
# Current Loss: 0.1603	 Last Loss: 0.1603
# Trigger Times: 7
# trigger times: 7
# Prediction: tensor([[218.2836, 209.9106, 207.5888, 210.3264, 219.6109, 232.5438, 237.4840]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 53: train loss 0.1217, validation loss 0.1603
# Current Loss: 0.1603	 Last Loss: 0.1603
# Trigger Times: 8
# trigger times: 8
# Prediction: tensor([[218.2776, 209.9064, 207.5868, 210.3248, 219.6097, 232.5432, 237.4852]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 54: train loss 0.1217, validation loss 0.1603
# Current Loss: 0.1603	 Last Loss: 0.1603
# Trigger Times: 9
# trigger times: 9
# Prediction: tensor([[218.2698, 209.8999, 207.5817, 210.3207, 219.6064, 232.5402, 237.4833]])
# Ground truth: tensor([[215., 202., 192., 181., 170., 163., 161.]])
# Epoch 55: train loss 0.1217, validation loss 0.1603
# Current Loss: 0.1603	 Last Loss: 0.1603
# Trigger Times: 10
# Early stopping!
# Start to test process.

# %%
#Function for creating pandas dataframe with the predicted 7 days. This way the model can be observed out of this notebook as well.
def get_predictions(model):
    pred = pd.DataFrame(
        data=model(X_valid).detach().numpy(),
        index=data_valid[pastWindow-1:-windowSize].index,
        columns=["1day","2day","3day","4day","5day","6day","7day"])
    return pred

#Get the dataframe for both model
predCNN = get_predictions(model)
predCNNSpat = get_predictions(modelSpat)

# %%
import os
from google.colab import drive
#Mounting Colab to Google Drive.
drive.mount('/content/drive/')

#Creating directory for the models.
# !mkdir -p "/content/drive/My Drive/ColabNotebooks/ECMI/Models"

#Created filename
fName = "LSTMmodel_s_loss3.csv"

#Saving prediction result file to the cloud computer.
predCNN.to_csv(fName, ',')

#Copy the created file to Drive.
# !cp -r '/content/'+fName "/content/drive/My Drive/ColabNotebooks/ECMI/Models"

#Changing file name for spatial model to be able to distuingish the result
fName = fName+"Spat"

#Saving prediction result file to the cloud computer.
predCNNSpat.to_csv(fName, ',')

#Copy the created file to Drive.
# !cp -r '/content/'+fName "/content/drive/My Drive/ColabNotebooks/ECMI/Models"
# Out:
# Mounted at /content/drive/
# cp: cannot stat '/content/+fName': No such file or directory
# cp: cannot stat '/content/+fName': No such file or directory

# %%
# Write standardization parameters to Google Drive
# Data Mean
with open('/content/drive/My Drive/ColabNotebooks/ECMI/Models/paramsMean.csv', 'w') as f:
  mlist = ["{}\n".format(i) for i in means[0]]
  f.writelines(mlist)
# Data Standard Deviation
with open('/content/drive/My Drive/ColabNotebooks/ECMI/Models/paramsSTDS.csv', 'w') as f:
  mlist = ["{}\n".format(i) for i in stds[0]]
  f.writelines(mlist)
# Mean only for Szeged to calculate in the case of Y values
with open('/content/drive/My Drive/ColabNotebooks/ECMI/Models/paramsYMean.csv', 'w') as f:
  mlist = ["{}\n".format(i) for i in y_mean[0]]
  f.writelines(mlist)
# Standard Deviation only for Szeged to calculate in the case of Y values
with open('/content/drive/My Drive/ColabNotebooks/ECMI/Models/paramsYSTDS.csv', 'w') as f:
  mlist = ["{}\n".format(i) for i in y_stds[0]]
  f.writelines(mlist)
